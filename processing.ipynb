# %%
import pandas as pd

# %%
df = pd.read_csv('./database/tevetronIC.csv')
print(df)
# Out:
#            Part Number                Price                 Package   Qty
# 0      WT8043-WELTREND  14,73 € (110,98 kn)                      IC     2
# 1         WS82C55AG-5P     0,00 € (0,00 kn)            IC=UPD8255C2     0
# 2     W29C040T-WINBOND   10,62 € (80,02 kn)           IC-SMD 32 PIN    10
# 3          W29C040T-90     0,00 € (0,00 kn)  IC=AT29C040A-12TI=10TI     0
# 4         W28Q32BVSSIG    3,28 € (24,71 kn)                      IC    20
# ...                ...                  ...                     ...   ...
# 8305             1431T     0,00 € (0,00 kn)              IC=LM317LZ     0
# 8306            1207AP     0,00 € (0,00 kn)                      IC     0
# 8307      1207A-IC-SMD     0,00 € (0,00 kn)                     NaN     0
# 8308          1014AP06     0,00 € (0,00 kn)                      IC     0
# 8309         1.5KE240A     0,00 € (0,00 kn)                     NaN     0
#
# [8310 rows x 4 columns]

# %%
df2 = pd.read_csv('./database/elmatisIC.csv')
print(df2)
# Out:
#          Part Number      Price  Description         Qty
# 0           10177330   3,98 EUR         I.C.       dodaj
# 1     10295090C9T25B   3,98 EUR         I.C.       dodaj
# 2        112070300A4   3,98 EUR         I.C.       dodaj
# 3            14DN157   3,98 EUR         I.C.       dodaj
# 4            14DN158   3,98 EUR         I.C.       dodaj
# ...              ...        ...          ...         ...
# 8459          TLP721   8,00 EUR  Opto kopler  nedostupno
# 8460         TLP741G  15,00 EUR  Opto kopler  nedostupno
# 8461         TLP748J   1,99 EUR  Opto kopler       dodaj
# 8462    TLP759  DIP8   2,65 EUR  Opto kopler       dodaj
# 8463          VTL5C4  10,62 EUR  Opto kopler       dodaj
#
# [8464 rows x 4 columns]
